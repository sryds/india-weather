# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker
from matplotlib.ticker import MultipleLocator

# %%
path = r'C:\Users\artoe\Documents\DataAnalytics\projects\india weather'

# %%
df = pd.read_pickle(os.path.join(path, 'data', 'daily_weather_updated_2.pkl'))

# %% [markdown]
# ## Exploring Relationships between Variables

# %% [markdown]
# ### Correlation between Variables

# %%
corr_sub = df[['temperature_2m_max', 'temperature_2m_min', 'temperature_2m_mean', 'apparent_temperature_max', 'apparent_temperature_min', 'apparent_temperature_mean','temp_diff_min', 'temp_diff_max', 'temp_diff_mean','precipitation_sum', 'rain_sum', 'weather_code', 'wind_speed_10m_max', 'wind_gusts_10m_max', 'wind_direction_10m_dominant']]

# %%
corr_sub.corr()
# Out:
#                              temperature_2m_max  temperature_2m_min  \
# temperature_2m_max                     1.000000            0.700101
# temperature_2m_min                     0.700101            1.000000
# temperature_2m_mean                    0.913329            0.930197
# apparent_temperature_max               0.898065            0.870750
# apparent_temperature_min               0.591302            0.970569
# apparent_temperature_mean              0.760364            0.965242
# temp_diff_min                          0.248321            0.718513
# temp_diff_max                          0.224780            0.693491
# temp_diff_mean                         0.242245            0.723726
# precipitation_sum                     -0.171679            0.177757
# rain_sum                              -0.171679            0.177757
# weather_code                          -0.113443            0.411934
# wind_speed_10m_max                     0.176743            0.386666
# wind_gusts_10m_max                     0.159742            0.372513
# wind_direction_10m_dominant            0.076199            0.039722
#
#                              temperature_2m_mean  apparent_temperature_max  \
# temperature_2m_max                      0.913329                  0.898065
# temperature_2m_min                      0.930197                  0.870750
# temperature_2m_mean                     1.000000                  0.958250
# apparent_temperature_max                0.958250                  1.000000
# apparent_temperature_min                0.857483                  0.837818
# apparent_temperature_mean               0.941353                  0.949637
# temp_diff_min                           0.537422                  0.604548
# temp_diff_max                           0.511051                  0.630473
# temp_diff_mean                          0.537272                  0.633783
# precipitation_sum                       0.013122                 -0.017396
# rain_sum                                0.013122                 -0.017396
# weather_code                            0.176611                  0.165140
# wind_speed_10m_max                      0.311373                  0.136111
# wind_gusts_10m_max                      0.294562                  0.117715
# wind_direction_10m_dominant             0.061824                  0.027193
#
#                              apparent_temperature_min  \
# temperature_2m_max                           0.591302
# temperature_2m_min                           0.970569
# temperature_2m_mean                          0.857483
# apparent_temperature_max                     0.837818
# apparent_temperature_min                     1.000000
# apparent_temperature_mean                    0.966697
# temp_diff_min                                0.864862
# temp_diff_max                                0.812532
# temp_diff_mean                               0.859389
# precipitation_sum                            0.208929
# rain_sum                                     0.208929
# weather_code                                 0.487210
# wind_speed_10m_max                           0.301802
# wind_gusts_10m_max                           0.296489
# wind_direction_10m_dominant                  0.020474
#
#                              apparent_temperature_mean  temp_diff_min  \
# temperature_2m_max                            0.760364       0.248321
# temperature_2m_min                            0.965242       0.718513
# temperature_2m_mean                           0.941353       0.537422
# apparent_temperature_max                      0.949637       0.604548
# apparent_temperature_min                      0.966697       0.864862
# apparent_temperature_mean                     1.000000       0.779785
# temp_diff_min                                 0.779785       1.000000
# temp_diff_max                                 0.761903       0.901027
# temp_diff_mean                                0.790348       0.973325
# precipitation_sum                             0.111761       0.232855
# rain_sum                                      0.111761       0.232855
# weather_code                                  0.357050       0.548398
# wind_speed_10m_max                            0.237026       0.065599
# wind_gusts_10m_max                            0.225353       0.079755
# wind_direction_10m_dominant                   0.024498      -0.023672
#
#                              temp_diff_max  temp_diff_mean  precipitation_sum  \
# temperature_2m_max                0.224780        0.242245          -0.171679
# temperature_2m_min                0.693491        0.723726           0.177757
# temperature_2m_mean               0.511051        0.537272           0.013122
# apparent_temperature_max          0.630473        0.633783          -0.017396
# apparent_temperature_min          0.812532        0.859389           0.208929
# apparent_temperature_mean         0.761903        0.790348           0.111761
# temp_diff_min                     0.901027        0.973325           0.232855
# temp_diff_max                     1.000000        0.976510           0.264419
# temp_diff_mean                    0.976510        1.000000           0.255529
# precipitation_sum                 0.264419        0.255529           1.000000
# rain_sum                          0.264419        0.255529           1.000000
# weather_code                      0.566018        0.571798           0.460591
# wind_speed_10m_max               -0.010371        0.027100           0.182953
# wind_gusts_10m_max               -0.021122        0.028446           0.207712
# wind_direction_10m_dominant      -0.074225       -0.051019           0.008890
#
#                              rain_sum  weather_code  wind_speed_10m_max  \
# temperature_2m_max          -0.171679     -0.113443            0.176743
# temperature_2m_min           0.177757      0.411934            0.386666
# temperature_2m_mean          0.013122      0.176611            0.311373
# apparent_temperature_max    -0.017396      0.165140            0.136111
# apparent_temperature_min     0.208929      0.487210            0.301802
# apparent_temperature_mean    0.111761      0.357050            0.237026
# temp_diff_min                0.232855      0.548398            0.065599
# temp_diff_max                0.264419      0.566018           -0.010371
# temp_diff_mean               0.255529      0.571798            0.027100
# precipitation_sum            1.000000      0.460591            0.182953
# rain_sum                     1.000000      0.460591            0.182953
# weather_code                 0.460591      1.000000            0.215158
# wind_speed_10m_max           0.182953      0.215158            1.000000
# wind_gusts_10m_max           0.207712      0.280982            0.906837
# wind_direction_10m_dominant  0.008890     -0.014757            0.148269
#
#                              wind_gusts_10m_max  wind_direction_10m_dominant
# temperature_2m_max                     0.159742                     0.076199
# temperature_2m_min                     0.372513                     0.039722
# temperature_2m_mean                    0.294562                     0.061824
# apparent_temperature_max               0.117715                     0.027193
# apparent_temperature_min               0.296489                     0.020474
# apparent_temperature_mean              0.225353                     0.024498
# temp_diff_min                          0.079755                    -0.023672
# temp_diff_max                         -0.021122                    -0.074225
# temp_diff_mean                         0.028446                    -0.051019
# precipitation_sum                      0.207712                     0.008890
# rain_sum                               0.207712                     0.008890
# weather_code                           0.280982                    -0.014757
# wind_speed_10m_max                     0.906837                     0.148269
# wind_gusts_10m_max                     1.000000                     0.142413
# wind_direction_10m_dominant            0.142413                     1.000000

# %%
corr_sub.corr().to_clipboard()

# %%
f = plt.figure(figsize=(8, 8))
plt.matshow(corr_sub.corr(), fignum=f.number)
plt.xticks(range(corr_sub.shape[1]), corr_sub.columns, fontsize=6, rotation=65.5)
plt.yticks(range(corr_sub.shape[1]), corr_sub.columns, fontsize=8)
cb = plt.colorbar() 
cb.ax.tick_params(labelsize=14) 
plt.title('Correlation Matrix', fontsize=14)
plt.show()

# %% [markdown]
# The numbers in this correlation matrix represent the strength of the relationship between each variable. A correlation coefficient of 1 indicates a perfectly matching relationship, a coefficient of 0 indicates no relationship at all. A negative value indicates an inverse relationship.
#
# As noted before, weather codes with higher numbers indicate, in this data, increasing clouds and precipitation.
#
# #### Observations:
#
# Wind direction does not have any significant effect on other weather conditions nor on the weather code assigned.
#
# Maximum temperature does not appear to have any correlation with the weather code (possibly due to all of the cities listed having a subtropical/tropical monsoon climate)
#
# Precipitation and rain have the strongest correlation with weather code (again, due to higher numbers representing rainier conditions)
#
# Precipitation and rain correlate perfectly (again, due to the warm climate of the cities contained, there is not likely to be other forms of precipitation such as snow, sleet, etc.)

# %%
f.savefig(os.path.join(path, 'visualizations','correlation_matrix.png'))

# %% [markdown]
# ## Frequency of Weather Codes across Cities

# %%
# understanding the weather code values
weathercode_dict = dict(zip(df['weather_code'], df['wmo_description']))

# %%
weathercode_dict
# Out:
# {0: 'Cloud development not observed or not observable',
#  3: 'Clouds generally forming or developing',
#  63: 'Rain, not freezing, continuous, moderate at time of observation',
#  53: 'Drizzle, not freezing, continuous, moderate at time of observation',
#  2: 'State of sky on the whole unchanged',
#  1: 'Clouds generally dissolving or becoming less developed',
#  51: 'Drizzle, not freezing, continuous, slight at time of observation',
#  61: 'Rain, not freezing, continuous, slight at time of observation',
#  55: 'Drizzle, not freezing, continuous, heavy (dense) at time of observation',
#  65: 'Rain, not freezing, continuous, heavy at time of observation'}

# %%
#show the distribution of weather codes across whole data set
hist = sns.histplot(df['weather_code'], bins = 50, kde = True)

# %%
hist.figure.savefig(os.path.join(path, 'visualizations','weathercode_histogram.png'))

# %% [markdown]
# At least half of all records in this dataset show weather codes from 0 to 10, in this case, codes 0, 1, 2 and 3. This means that at least half the days recorded did not have any rain or precipitation.

# %%
# Pivot data to get counts of each weather condition per city
pivot_df = df.groupby(['city', 'weather_code']).size().unstack(fill_value=0)

# Render a single consolidated grid heatmap
plt.figure(figsize=(10, 6))
heat = sns.heatmap(pivot_df, annot=True, fmt='d', cmap='YlGnBu', cbar_kws={'label': 'Frequency'})
plt.title('Weather Code Frequency Matrix by City, 2000-2024')
plt.ylabel('City')
plt.xlabel('Weather Code')
plt.tight_layout()
plt.show()

# %%
heat.figure.savefig(os.path.join(path, 'visualizations','weathercode_freqmatrix_bycity_allyears.png'))

# %% [markdown]
# ### Observations
#
# Ahmedabad had the highest frequency of clear days (weather code 0), Chennai had the lowest frequency. This was also the most commonly-observed weather code for Delhi, Jaipur and Lucknow.
#
# Bangalore, Chennai and Hyderabad had the highest frequency of generally-cloudy days (weather code 3). This was also the most commonly-observed weather code for Mumbai, Kolkata and Pune.
#
# Chennai, Bangalore and Hyderabad had the highest frequency of days with light drizzle (weather code 51).
#
# Weather codes 55 (heavy, continuous drizzle) and 65 (heavy, continuous rain) were the least common across all cities. Bangalore, Chennai and Pune showed the highest frequency of weather code 55, while Kolkata showed the highest frequency of weather code 65.
#
# Kolkata also showed the highest frequency of weather code 63 (moderate rain) compared to other cities.

# %% [markdown]
# ### Weather Code Frequency for All Cities, Selected Years

# %%
#create a subset for each year
df_2000 =  df[df['year']==2000]
df_2012 =  df[df['year']==2012]
df_2024 =  df[df['year']==2024]

# %%
pivot_2000 = df_2000.groupby(['city', 'weather_code']).size().unstack(fill_value=0)

# Render a single consolidated grid heatmap
plt.figure(figsize=(10, 6))
heat2 = sns.heatmap(pivot_2000, annot=True, fmt='d', cmap='YlGnBu', cbar_kws={'label': 'Frequency'})
plt.title('Weather Code Frequency Matrix by City, 2000')
plt.ylabel('City')
plt.xlabel('Weather Code')
plt.tight_layout()
plt.show()

# %%
heat2.figure.savefig(os.path.join(path, 'visualizations','weathercode_freqmatrix_bycity_2000.png'))

# %%
pivot_2012 = df_2012.groupby(['city', 'weather_code']).size().unstack(fill_value=0)

# Render a single consolidated grid heatmap
plt.figure(figsize=(10, 6))
heat3 = sns.heatmap(pivot_2012, annot=True, fmt='d', cmap='YlGnBu', cbar_kws={'label': 'Frequency'})
plt.title('Weather Code Frequency Matrix by City, 2012')
plt.ylabel('City')
plt.xlabel('Weather Code')
plt.tight_layout()
plt.show()

# %%
heat3.figure.savefig(os.path.join(path, 'visualizations','weathercode_freqmatrix_bycity_2012.png'))

# %%
pivot_2024 = df_2024.groupby(['city', 'weather_code']).size().unstack(fill_value=0)

# Render a single consolidated grid heatmap
plt.figure(figsize=(10, 6))
heat4 = sns.heatmap(pivot_2024, annot=True, fmt='d', cmap='YlGnBu', cbar_kws={'label': 'Frequency'})
plt.title('Weather Code Frequency Matrix by City, 2024')
plt.ylabel('City')
plt.xlabel('Weather Code')
plt.tight_layout()
plt.show()

# %%
heat4.figure.savefig(os.path.join(path, 'visualizations','weathercode_freqmatrix_bycity_2024.png'))

# %% [markdown]
# ### Observations
#
# Ahmedabad's precipitation levels appear to have increased between 2000 and 2024, with fewer occurrences of weather code 0 (clear skies) and increasing numbers of days with cloudy and rainy conditions.
#
# Weather code 65 (heavy, continuous, non-freezing rain) appears to have increased in overal frequency betweeen 2012 and 2024, with all cities showing higher counts of this weather code in 2024.

# %% [markdown]
# ## Other Correlations

# %% [markdown]
# ### Correlation between Wind and Rain

# %%
line1 = sns.lmplot(x = 'rain_sum', y = 'wind_speed_10m_max', data = df)

# %%
line1.figure.savefig(os.path.join(path, 'visualizations','windspeed_rain_lmplot.png'))

# %%
line2 = sns.lmplot(x = 'rain_sum', y = 'wind_gusts_10m_max', data = df)

# %%
line2.figure.savefig(os.path.join(path, 'visualizations','windgusts_rain_lmplot.png'))

# %% [markdown]
# ### Correlation between Apparent Temperature and Rain

# %%
line3 = sns.lmplot(x = 'rain_sum', y = 'temp_diff_max', data = df)

# %%
line3.figure.savefig(os.path.join(path, 'visualizations','maxtempdiff_rain_lmplot.png'))

# %%
line4 = sns.lmplot(x = 'rain_sum', y = 'temp_diff_min', data = df)

# %%
line4.figure.savefig(os.path.join(path, 'visualizations','mintempdiff_rain_lmplot.png'))

# %%
line5 = sns.lmplot(x = 'rain_sum', y = 'temp_diff_mean', data = df)

# %%
line5.figure.savefig(os.path.join(path, 'visualizations','meantempdiff_rain_lmplot.png'))

# %% [markdown]
# ### Observations
#
# There is a positive correlation between rain and the difference between apparent and actual temperature.
#
# There is a weaker positive correlation between rain and wind speed, as well as rain and wind gusts.
#
# Rain data is heavily skewed to the right, with a large number of records showing 0 rain.
#
# Further data on humidity levels and cloud cover would also be helpful in determining the cause of higher and lower apparent temperatures.

# %% [markdown]
# ### Correlation between Perceived Temperature and Max Wind Speed

# %%
line6 = sns.lmplot(x = 'wind_speed_10m_max', y = 'temp_diff_mean', data = df)

# %%
line6.figure.savefig(os.path.join(path, 'visualizations','meantempdiff_windspeed_lmplot.png'))

# %%
line7 = sns.lmplot(x = 'wind_speed_10m_max', y = 'temp_diff_min', data = df)

# %%
line7.figure.savefig(os.path.join(path, 'visualizations','mintempdiff_windspeed_lmplot.png'))

# %%
line8 = sns.lmplot(x = 'wind_speed_10m_max', y = 'temp_diff_max', data = df)

# %%
line8.figure.savefig(os.path.join(path, 'visualizations','maxtempdiff_windspeed_lmplot.png'))

# %% [markdown]
# ### Observations
#
# All correlations between wind speed and its effect on apparent temperature are very weak.
#
# There is a noticeable positive correlation between wind speed and the difference between actual and apparent minimum temperatures. This indicates that higher wind speeds cause minimum temperatures to feel colder than they are.
#
# There is a slight negative correlation between wind speed and the difference between actual and apparent maximum temperature. Again, this indicates the cooling effect of higher wind speeds.
